# %% [markdown]
# <a href="https://colab.research.google.com/github/26494-taitan/23-programming-portfolio--/blob/main/mid_23_Taitan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# mid-23-Taitan-py

# %%
score = int(input("กรุณาใส่คะแนนสอบด้วยค้าบ: "))
if score >= 50 :
  print("pass")
else:
  print("fail")
